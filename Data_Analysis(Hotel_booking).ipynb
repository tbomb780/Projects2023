# %% [markdown]
# <a href="https://colab.research.google.com/github/tbomb780/Projects2023/blob/main/Data_Analysis(Hotel_booking).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Problem statement
# #Why there is a high number of cancelations in  Hotel Booking?

# %% [markdown]
# #Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Loading the dataset
# from https://www.kaggle.com/datasets/mojtaba142/hotel-booking

# %%
df= pd.read_csv('/content/hotel_booking.csv')

# %% [markdown]
# #Exploratory Data Analysis or Exploring the dataset

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 74707  City Hotel            0          0               2015
# 74708  City Hotel            0          0               2016
# 74709  City Hotel            0          0               2016
# 74710  City Hotel            0          1               2016
# 74711  City Hotel            0          2               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 74707           December                        50                         11
# 74708            January                         2                          5
# 74709            January                         3                         13
# 74710            January                         4                         22
# 74711            January                         5                         27
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df.shape
# Out:
# (74712, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74712 entries, 0 to 74711
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           74712 non-null  object
#  1   is_canceled                     74712 non-null  int64
#  2   lead_time                       74712 non-null  int64
#  3   arrival_date_year               74712 non-null  int64
#  4   arrival_date_month              74712 non-null  object
#  5   arrival_date_week_number        74712 non-null  int64
#  6   arrival_date_day_of_month       74712 non-null  int64
#  7   stays_in_weekend_nights         74712 non-null  int64
#  8   stays_in_week_nights            74712 non-null  int64
#  9   adults                          74712 non-null  int64
#  10  children                        74708 non-null  float64
#  11  babies                          74712 non-null  int64
# ...

# %%
df['reservation_status_date']= pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74712 entries, 0 to 74711
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           74712 non-null  object
#  1   is_canceled                     74712 non-null  int64
#  2   lead_time                       74712 non-null  int64
#  3   arrival_date_year               74712 non-null  int64
#  4   arrival_date_month              74712 non-null  object
#  5   arrival_date_week_number        74712 non-null  int64
#  6   arrival_date_day_of_month       74712 non-null  int64
#  7   stays_in_weekend_nights         74712 non-null  int64
#  8   stays_in_week_nights            74712 non-null  int64
#  9   adults                          74712 non-null  int64
#  10  children                        74708 non-null  float64
#  11  babies                          74712 non-null  int64
# ...

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  74712.000000  74712.000000       74712.000000
# mean       0.535563    112.180025        2016.122604
# std        0.498737    110.234160           0.725968
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     23.000000        2016.000000
# 50%        1.000000     79.000000        2016.000000
# 75%        1.000000    170.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              74712.000000               74712.000000
# mean                  27.290275                  15.765593
# std                   13.552640                   8.815437
# min                    1.000000                   1.000000
# 25%                   17.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df.describe(include='object')
# Out:
#                hotel arrival_date_month   meal country market_segment  \
# count          74712              74712  74712   74226          74712
# unique             2                 12      5     151              8
# top     Resort Hotel             August     BB     PRT      Online TA
# freq           40060               9096  57738   35635          34054
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                 74712              74712              74712
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  61245              51703              43821
#
#        deposit_type customer_type reservation_status          name  \
# count         74712         74712              74712         74712
# unique            3             4                  3         56318
# top      No Deposit     Transient           Canceled  Robert Smith
# ...

# %%
for col in df.describe(include='object').columns:
  print(col)
  print(df[col].unique())
  print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %% [markdown]
# #Check for the missing Values and remove them.

# %%
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             486
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df.drop(['company','agent'],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
#Average daily rate(adr) or time contains outlier
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
#Removing Outlier
df=df[df['adr']<5000]

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  74221.000000  74221.000000       74221.000000
# mean       0.538136    112.712871        2016.124129
# std        0.498547    110.280724           0.726147
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     24.000000        2016.000000
# 50%        1.000000     80.000000        2016.000000
# 75%        1.000000    171.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              74221.000000               74221.000000
# mean                  27.294054                  15.769540
# std                   13.528080                   8.814796
# min                    1.000000                   1.000000
# 25%                   17.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# #Data Analysis and Visualizations

# %%
cancelled_percent= df['is_canceled'].value_counts(normalize=True)
print(cancelled_percent)
plt.figure(figsize=(5,4))
plt.title('Reservation status count')
plt.bar(['Not canceled', 'Canceled'], df['is_canceled'].value_counts(), edgecolor='k', width=0.7)
plt.show
# Out:
# 1    0.538136
# 0    0.461864
# Name: is_canceled, dtype: float64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,4))
ax1=sns.countplot(x='hotel',hue='is_canceled',data=df,palette='Blues')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status in different hotels', size= 20)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
plt.legend(['not canceled','canceled'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
resort_hotel = df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
city_hotel = df[df['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 1    0.833617
# 0    0.166383
# Name: is_canceled, dtype: float64

# %% [markdown]
# #Finding:-27% of Resort hotels are getting canceled but 83% of City hotels are getting cancelled may be due to price.

# %%
resort_hotel= resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel= city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize=30)
plt.plot(resort_hotel.index,resort_hotel['adr'],label='Resort Hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label='City Hotel')
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# #There is a spike in the price of Resort hotels and City hotels that may be on the weekends.

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(16,8))
ax1 = sns.countplot(x='month', hue='is_canceled', data=df, palette='bright')
legend_labels,_=ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status per month',size=20)
plt.xlabel('month')
plt.ylabel('number of reservations')
plt.legend(['not canceled','canceled'])
plt.show()

# %% [markdown]
# 8th,9th month august,september have highest booking and 1st month january have highest cancellation.

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per month', fontsize=30)
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()
#Average daily rate per month

# %% [markdown]
# #The data shows the highest price in January and the lowest price in August and September. price is a factor in cancelation. The 11th month shows an equal amount of cost booking and cancelation.

# %% [markdown]
# #Analysing top 10 Countries

# %%
cancelled_data= df[df['is_canceled']==1]
top_10_country=cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country,autopct='%.2f',labels=top_10_country.index)
plt.show()

# %% [markdown]
# #Finding:-highest cancelations are from Portugal country.
# #Need to improve customer experience price and offers for Portugal tourists.

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        33979
# Groups           15039
# Offline TA/TO    14451
# Direct            7742
# Corporate         2689
# Complementary      280
# Aviation            41
# Name: market_segment, dtype: int64

# %% [markdown]
# #Finding:- Most customers 33979 are aquired through online Travel Agents.

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.457808
# Groups           0.202625
# Offline TA/TO    0.194702
# Direct           0.104310
# Corporate        0.036230
# Complementary    0.003773
# Aviation         0.000552
# Name: market_segment, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.507649
# Groups           0.254651
# Offline TA/TO    0.170902
# Direct           0.044791
# Corporate        0.019379
# Complementary    0.001602
# Aviation         0.001027
# Name: market_segment, dtype: float64

# %% [markdown]
# #Finding:-45% of bookings are online and 50% of cancelations are online.
# #The reason could be the online picture of the hotel and the real hotel condition is different.

# %%
#Proof with data visualization Higher price leads to higher cancelation.
cancelled_df_adr= cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

not_cancelled_data=df[df['is_canceled']==0]
not_cancelled_df_adr=not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date',inplace=True)
#ploting graph between cancel and average daily rate
plt.figure(figsize=(20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.legend()

# %%
#For clear picture we will filter spread data.
cancelled_df_adr= cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016')&(cancelled_df_adr['reservation_status_date']<'2017-09')]
not_cancelled_df_adr= not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016')&(not_cancelled_df_adr['reservation_status_date']<'2017-09')]
# 2016 and 2017 data plot
plt.figure(figsize=(20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.legend(fontsize=20)
plt.show()
